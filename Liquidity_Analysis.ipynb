# %%
import matplotlib.pyplot as plt
plt.plot(df["timestamp"], predictor.model.predict_proba(predictor.scaler.transform(predictor.fe.build_features(df)))[:,1])
plt.title("Liquidity Risk Over Time")
plt.xlabel("Timestamp")
plt.ylabel("Risk Score")
plt.show()
